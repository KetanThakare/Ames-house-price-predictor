# %%
import pandas as pd
import numpy as np

ah_data=pd.read_csv('C:/Users/admin/Desktop/EeD/Python/Project/AmesHousingData.csv')
#to display all cloumns
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 1000)
ah_data.sample(5)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 257    258          20       RL         68.0     8814   Pave   NaN      Reg
# 2564  2565          20       RL        126.0    13108   Pave   NaN      IR2
# 1063  1064          30       RM         50.0     6000   Pave   NaN      Reg
# 1837  1838         190       RM         60.0    10320   Pave  Grvl      Reg
# 2876  2877          70       RL         69.0     4899   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 257          Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 2564         HLS    AllPub    Inside       Gtl      Crawfor       Norm
# 1063         Lvl    AllPub    Inside       Gtl      OldTown     Artery
# 1837         Bnk    AllPub    Inside       Gtl       IDOTRR     Artery
# 2876         HLS    AllPub    Corner       Gtl        SWISU       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
from sklearn.base import TransformerMixin

class DataFrameImputer(TransformerMixin):

    def __init__(self):
        """Impute missing values.

        Columns of dtype object are imputed with the most frequent value 
        in column.

        Columns of other types are imputed with mean of column.

        """
    def fit(self, X, y=None):

        self.fill = pd.Series([X[c].value_counts().index[0]
            if X[c].dtype == np.dtype('O') else X[c].mean() for c in X],
            index=X.columns)

        return self

    def transform(self, X, y=None):
        return X.fillna(self.fill)

ah_data = DataFrameImputer().fit_transform(ah_data)
ah_data.sample(5)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1097  1098         120       RL    69.305795     3696   Pave  Grvl      Reg
# 1602  1603          30  C (all)    66.000000     8712   Grvl  Grvl      Reg
# 169    170          20       RL    69.305795    16669   Pave  Grvl      IR1
# 1822  1823          30  C (all)    72.000000     9392   Pave  Grvl      Reg
# 2321  2322          20       RL    53.000000     3710   Pave  Grvl      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 1097         Lvl    AllPub    Inside       Gtl      StoneBr       Norm
# 1602         Lvl    AllPub    Corner       Gtl       IDOTRR       Norm
# 169          Lvl    AllPub    Corner       Gtl       Timber       Norm
# 1822         Lvl    AllPub    Corner       Gtl       IDOTRR       Norm
# 2321         Lvl    AllPub    Inside       Gtl      Blmngtn       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
#preprocessing the data
#missing values filtering
missing_values_count = ah_data.isnull().sum()
missing_values_count[missing_values_count > 0]
#checking data types
#ah_data.dtypes

#all_columns = ah_data.columns
#len(all_columns)
#columns should be equal to 80

#seggregating columns as per data type
integer_columns = ah_data.select_dtypes(include=['int64']).columns.tolist()
integer_columns = integer_columns[1:60]
char_text_columns = ah_data.select_dtypes(include=['object']).columns.tolist()
float_columns = ah_data.select_dtypes(include = ['float64']).columns.tolist()
#check if number of columns are right
len(char_text_columns) + len(integer_columns) +len(float_columns) 

ah_data[float_columns] = ah_data[float_columns].astype(np.int64)

ah_data.dtypes
# Out:
# Id                int64
# MSSubClass        int64
# MSZoning         object
# LotFrontage       int64
# LotArea           int64
# Street           object
# Alley            object
# LotShape         object
# LandContour      object
# Utilities        object
# LotConfig        object
# LandSlope        object
# Neighborhood     object
# Condition1       object
# Condition2       object
# BldgType         object
# HouseStyle       object
# OverallQual       int64
# OverallCond       int64
# YearBuilt         int64
# YearRemodAdd      int64
# RoofStyle        object
# RoofMatl         object
# Exterior1st      object
# Exterior2nd      object
# MasVnrType       object
# MasVnrArea        int64
# ExterQual        object
# ExterCond        object
# Foundation       object
# BsmtQual         object
# BsmtCond         object
# BsmtExposure     object
# BsmtFinType1     object
# BsmtFinSF1        int64
# BsmtFinType2     object
# BsmtFinSF2        int64
# BsmtUnfSF         int64
# ...

# %%
#from sklearn.preprocessing import Imputer
#imputer = Imputer(missing_values = 'NaN', strategy = 'mean', axis = 0)
#imputer = imputer.fit(ah_data[integer_columns])
#imputer.transform(ah_data[integer_columns])

#ah_data.loc[:,integer_columns] = ah_data.loc[:,integer_columns].fillna(ah_data.mean())
#ah_data.loc[integer_columns]

#ah_data.isnull().sum()
#missing_values_count = ah_data.isnull().sum()
#missing_values_count[missing_values_count > 0]

#ah_data.loc[:,char_text_columns] = 
#ah_data.loc[:,char_text_columns].fillna(ah_data.mode())

# %%
#ah_data.sample(10)

missing_values_count = ah_data.isnull().sum()
missing_values_count
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
# Street           0
# Alley            0
# LotShape         0
# LandContour      0
# Utilities        0
# LotConfig        0
# LandSlope        0
# Neighborhood     0
# Condition1       0
# Condition2       0
# BldgType         0
# HouseStyle       0
# OverallQual      0
# OverallCond      0
# YearBuilt        0
# YearRemodAdd     0
# RoofStyle        0
# RoofMatl         0
# Exterior1st      0
# Exterior2nd      0
# MasVnrType       0
# MasVnrArea       0
# ExterQual        0
# ExterCond        0
# Foundation       0
# BsmtQual         0
# BsmtCond         0
# BsmtExposure     0
# BsmtFinType1     0
# BsmtFinSF1       0
# BsmtFinType2     0
# BsmtFinSF2       0
# BsmtUnfSF        0
# TotalBsmtSF      0
# Heating          0
# HeatingQC        0
# CentralAir       0
# Electrical       0
# 1stFlrSF         0
# 2ndFlrSF         0
# LowQualFinSF     0
# GrLivArea        0
# ...

# %%
#one hot encoding the categorical variables
ah_dataOHE = pd.get_dummies(ah_data)
ah_dataOHE.sample(5)
#ah_dataOHE.info()
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 1024  1025          20           69    15498            8            6
# 2549  2550          20          128    39290           10            5
# 571    572          20           60     7332            6            6
# 628    629          60           70    11606            5            5
# 1676  1677         120           80    10307            7            5
#
#       YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  \
# 1024       1976          1976           0        1165         400          0
# 2549       2008          2009        1224        4010           0       1085
# 571        1959          1959         207         414           0        450
# 628        1969          1969         192         650           0        390
# 1676       2007          2008         176         876           0        474
#
# ...

# %%
#get location of SalePrice in dataset
#ah_dataOHE.columns.get_loc("SalePrice")
x = ah_dataOHE.loc[:, ah_dataOHE.columns != "SalePrice"]
y = ah_dataOHE.loc[:, 'SalePrice']
#print(x.sample(5))
#print(y.sample(5))
ah_dataOHE.dtypes
# Out:
# Id                       int64
# MSSubClass               int64
# LotFrontage              int64
# LotArea                  int64
# OverallQual              int64
# OverallCond              int64
# YearBuilt                int64
# YearRemodAdd             int64
# MasVnrArea               int64
# BsmtFinSF1               int64
# BsmtFinSF2               int64
# BsmtUnfSF                int64
# TotalBsmtSF              int64
# 1stFlrSF                 int64
# 2ndFlrSF                 int64
# LowQualFinSF             int64
# GrLivArea                int64
# BsmtFullBath             int64
# BsmtHalfBath             int64
# FullBath                 int64
# HalfBath                 int64
# BedroomAbvGr             int64
# KitchenAbvGr             int64
# TotRmsAbvGrd             int64
# Fireplaces               int64
# GarageYrBlt              int64
# GarageCars               int64
# GarageArea               int64
# WoodDeckSF               int64
# OpenPorchSF              int64
# ...

# %%
#feature selection
#Feature Selection
from sklearn.feature_selection import RFE
#from sklearn.feature_selection import RFECV
from sklearn.linear_model import LogisticRegression
#from sklearn.linear_model import LinearRegression
#from sklearn.svm import SVR
#model = SVR(kernel = "linear")
model = LogisticRegression()
#model = LinearRegression()
rfe = RFE(estimator = model, n_features_to_select=15)
#rfe = RFECV(estimator = model, cv = 5, step = 3)
fit = rfe.fit(x,y)
print("Num Features: %d"% fit.n_features_) 
print("Selected Features: %s"% fit.support_) 
print("Feature Ranking: %s"% fit.ranking_)
#select_features = fit.support_
#feature_ranking = fit.ranking_

# %% [markdown]
# from sklearn.feature_selection import SelectKBest
# from sklearn.feature_selection import f_classif
# X_new = SelectKBest(f_classif, k=15).fit_transform(x, y)
# print(X_new)

# %%
x_cn = x.columns
d = {'columnnames':x_cn, 'selectfeatures':select_features, 'ranking':feature_ranking}
temp_ahdata = pd.DataFrame(data = d)
#select_features.dtype
#x_cn.dtype
temp_ahdata[temp_ahdata.ranking == 1]
# Out:
#             columnnames  selectfeatures  ranking
# 37     MSZoning_C (all)            True        1
# 38          MSZoning_FV            True        1
# 39          MSZoning_RH            True        1
# 41          MSZoning_RM            True        1
# 164   MasVnrType_BrkCmn            True        1
# 165  MasVnrType_BrkFace            True        1
# 166     MasVnrType_None            True        1
# 167    MasVnrType_Stone            True        1
# 183         BsmtQual_Ex            True        1
# 184         BsmtQual_Fa            True        1
# 185         BsmtQual_Gd            True        1
# 186         BsmtQual_TA            True        1
# 247    GarageFinish_Fin            True        1
# 248    GarageFinish_RFn            True        1
# 249    GarageFinish_Unf            True        1
