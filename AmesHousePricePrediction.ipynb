# %%
import pandas as pd
import numpy as np

ah_data=pd.read_csv('C:/Users/admin/Desktop/EeD/Python/Project/AmesHousingData.csv')
#to display all cloumns
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 1000)
ah_data.sample(5)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 98      99          30       RL         85.0    10625   Pave   NaN      Reg
# 445    446          20       RL         73.0     9855   Pave   NaN      Reg
# 795    796          60       RL         70.0     8400   Pave   NaN      Reg
# 196    197          20       RL         79.0     9416   Pave   NaN      Reg
# 2910  2911         160       RM         21.0     1484   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 98           Lvl    AllPub    Corner       Gtl      Edwards       Norm
# 445          Lvl    AllPub    Corner       Gtl      Edwards       Norm
# 795          Lvl    AllPub    Inside       Gtl      SawyerW       Norm
# 196          Lvl    AllPub    Inside       Gtl      Somerst       Norm
# 2910         Lvl    AllPub    Inside       Gtl      MeadowV       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 98         Norm     1Fam     1Story            5            5       1920
# 445        Norm     1Fam     1Story            6            5       1956
# 795        Norm     1Fam     2Story            6            6       1980
# 196        Norm     1Fam     1Story            7            5       2007
# 2910       Norm   TwnhsE     2Story            4            4       1972
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 98            1950     Gable  CompShg     Wd Sdng     Wd Sdng       None
# 445           1956       Hip  CompShg     Wd Sdng     Wd Sdng       None
# 795           1981     Gable  CompShg     HdBoard     HdBoard    BrkFace
# 196           2007       Hip  CompShg     CemntBd     CmentBd      Stone
# 2910          1972     Gable  CompShg     CemntBd     CmentBd       None
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 98           0.0        TA        TA     BrkTil       TA       TA
# 445          0.0        TA        TA     CBlock       TA       TA
# 795        130.0        TA        TA     CBlock       Gd       TA
# 196        205.0        Ex        TA      PConc       Ex       TA
# 2910         0.0        TA        TA     CBlock       TA       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 98             No          ALQ       108.0          Unf         0.0
# 445            No          Unf         0.0          Unf         0.0
# 795            No          Unf         0.0          Unf         0.0
# 196            No          GLQ      1126.0          Unf         0.0
# 2910           No          Rec       252.0          Unf         0.0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# 98        350.0        458.0    GasA        Fa          N      SBrkr
# 445      1436.0       1436.0    GasA        Fa          Y      SBrkr
# 795       650.0        650.0    GasA        TA          Y      SBrkr
# 196       600.0       1726.0    GasA        Ex          Y      SBrkr
# 2910      294.0        546.0    GasA        TA          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 98         835         0             0        835           0.0           0.0
# 445       1689         0             0       1689           0.0           0.0
# 795        888       676             0       1564           0.0           0.0
# 196       1726         0             0       1726           1.0           0.0
# 2910       546       546             0       1092           0.0           0.0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 98           1         0             2             1          TA
# 445          1         0             3             1          TA
# 795          2         1             3             1          TA
# 196          2         0             3             1          Ex
# 2910         1         1             3             1          TA
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# 98               5        Typ           0         NaN    Basment       1920.0
# 445              7        Typ           1          Gd     Attchd       1956.0
# 795              7        Typ           1          TA     Attchd       1980.0
# 196              8        Typ           1          Gd     Attchd       2007.0
# 2910             5        Typ           0         NaN     Attchd       1972.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 98            Unf         1.0       366.0         Fa         TA          Y
# 445           Unf         2.0       480.0         TA         TA          Y
# 795           Unf         2.0       476.0         TA         TA          Y
# 196           Fin         3.0       786.0         TA         TA          Y
# 2910          Unf         1.0       253.0         TA         Fa          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 98             0            0             77          0            0
# 445            0            0              0          0            0
# 795            0           50              0          0          204
# 196          171          138              0          0          266
# 2910           0            0              0          0            0
#
#       PoolArea PoolQC  Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# 98           0    NaN    NaN        Shed      400       5    2010      COD
# 445          0    NaN  MnPrv         NaN        0      11    2009      COD
# 795          0    NaN  MnPrv         NaN        0       4    2010       WD
# 196          0    NaN    NaN         NaN        0       9    2007      New
# 2910         0    NaN    NaN         NaN        0       5    2006       WD
#
#      SaleCondition  SalePrice
# 98         Abnorml    83000.0
# 445         Normal   127500.0
# 795         Normal   171000.0
# 196        Partial   311872.0
# 2910        Normal        NaN

# %%
#preprocessing the data
#missing values filtering
missing_values_count = ah_data.isnull().sum()
missing_values_count[missing_values_count > 0]
#checking data types
#ah_data.dtypes

#all_columns = ah_data.columns
#len(all_columns)
#columns should be equal to 80

#seggregating columns as per data type
integer_columns = ah_data.select_dtypes(include=['int64','float64']).columns.tolist()
integer_columns = integer_columns[1:60]
char_text_columns = ah_data.select_dtypes(include=['object']).columns.tolist()

#check if number of columns are right
len(char_text_columns) + len(integer_columns)
# Out:
# 80

# %%
#from sklearn.preprocessing import Imputer
#imputer = Imputer(missing_values = 'NaN', strategy = 'mean', axis = 0)
#imputer = imputer.fit(ah_data[integer_columns])
#imputer.transform(ah_data[integer_columns])

#ah_data.loc[:,integer_columns] = ah_data.loc[:,integer_columns].fillna(ah_data.mean())
#ah_data.loc[integer_columns]

#ah_data.isnull().sum()
#missing_values_count = ah_data.isnull().sum()
#missing_values_count[missing_values_count > 0]

#ah_data.loc[:,char_text_columns] = 
#ah_data.loc[:,char_text_columns].fillna(ah_data.mode())
# Out:
# MSZoning           4
# Alley           2720
# Utilities          2
# Exterior1st        1
# Exterior2nd        1
# MasVnrType        24
# BsmtQual          81
# BsmtCond          82
# BsmtExposure      82
# BsmtFinType1      79
# BsmtFinType2      80
# Electrical         1
# KitchenQual        1
# Functional         2
# FireplaceQu     1419
# GarageType       157
# GarageFinish     159
# GarageQual       159
# GarageCond       159
# PoolQC          2907
# Fence           2347
# MiscFeature     2813
# SaleType           1
# dtype: int64

# %%
from sklearn.base import TransformerMixin

class DataFrameImputer(TransformerMixin):

    def __init__(self):
        """Impute missing values.

        Columns of dtype object are imputed with the most frequent value 
        in column.

        Columns of other types are imputed with mean of column.

        """
    def fit(self, X, y=None):

        self.fill = pd.Series([X[c].value_counts().index[0]
            if X[c].dtype == np.dtype('O') else X[c].mean() for c in X],
            index=X.columns)

        return self

    def transform(self, X, y=None):
        return X.fillna(self.fill)

ah_data = DataFrameImputer().fit_transform(ah_data)
ah_data.sample(5)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1777  1778          20       RL    60.000000     7626   Pave  Grvl      Reg
# 2901  2902          20       RL    69.305795     8098   Pave  Grvl      IR1
# 2351  2352          20       FV   100.000000    11824   Pave  Grvl      IR1
# 1347  1348          20       RL    93.000000    15306   Pave  Grvl      IR1
# 1338  1339          60       RL    95.000000    13450   Pave  Grvl      IR1
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 1777         Lvl    AllPub    Inside       Gtl        NAmes       Norm
# 2901         Lvl    AllPub    Inside       Gtl       Timber       Norm
# 2351         Lvl    AllPub    Corner       Gtl      Somerst       Norm
# 1347         HLS    AllPub    Corner       Gtl       Timber       Norm
# 1338         Lvl    AllPub    Corner       Gtl      CollgCr       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 1777       Norm     1Fam     1Story            5            8       1952
# 2901       Norm     1Fam     1Story            6            5       2000
# 2351       Norm     1Fam     1Story            8            5       2006
# 1347       Norm     1Fam     1Story            8            5       2006
# 1338       Norm     1Fam     2Story            7            5       2002
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 1777          2005       Hip  CompShg     Wd Sdng     Wd Sdng       None
# 2901          2000     Gable  CompShg     VinylSd     VinylSd       None
# 2351          2006     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1347          2007     Gable  CompShg     VinylSd     VinylSd      Stone
# 1338          2002     Gable  CompShg     VinylSd     VinylSd       None
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 1777         0.0        Gd        TA     CBlock       TA       TA
# 2901         0.0        Gd        TA       Wood       Gd       TA
# 2351       298.0        Gd        TA      PConc       Gd       TA
# 1347       100.0        Gd        TA      PConc       Ex       TA
# 1338         0.0        Gd        TA      PConc       Gd       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 1777           No          GLQ       931.0          Unf         0.0
# 2901           Av          GLQ      1136.0          BLQ       116.0
# 2351           Av          Unf         0.0          Unf         0.0
# 1347           Gd          GLQ        80.0          Unf         0.0
# 1338           No          GLQ       700.0          Unf         0.0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# 1777      100.0       1031.0    GasA        Gd          Y      SBrkr
# 2901      129.0       1381.0    GasA        Ex          Y      SBrkr
# 2351     1685.0       1685.0    GasA        Ex          Y      SBrkr
# 1347     1652.0       1732.0    GasA        Ex          Y      SBrkr
# 1338      216.0        916.0    GasA        Ex          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 1777      1031         0             0       1031           1.0           0.0
# 2901      1403         0             0       1403           1.0           0.0
# 2351      1685         0             0       1685           0.0           0.0
# 1347      1776         0             0       1776           1.0           0.0
# 1338       920       941             0       1861           1.0           0.0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 1777         1         0             2             1          Gd
# 2901         2         0             2             1          Gd
# 2351         2         0             2             1          Gd
# 1347         2         0             3             1          Gd
# 1338         2         1             3             1          Gd
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# 1777             5        Typ           0          Gd     Attchd       1952.0
# 2901             5        Typ           0          Gd     Attchd       2000.0
# 2351             5        Typ           1          Gd     Attchd       2006.0
# 1347             7        Typ           1          Gd     Attchd       2006.0
# 1338             8        Typ           0          Gd    BuiltIn       2002.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 1777          Unf         1.0       230.0         TA         TA          Y
# 2901          Unf         2.0       470.0         TA         TA          Y
# 2351          Fin         3.0       658.0         TA         TA          Y
# 1347          Fin         3.0       712.0         TA         TA          Y
# 1338          RFn         2.0       492.0         TA         TA          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 1777           0            0              0          0            0
# 2901           0          173              0          0            0
# 2351         112           63              0          0            0
# 1347           0            0              0          0            0
# 1338         146           91              0          0            0
#
#       PoolArea PoolQC  Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# 1777         0     Gd  MnPrv        Shed        0       3    2009       WD
# 2901         0     Gd  MnPrv        Shed        0      10    2006       WD
# 2351         0     Gd  MnPrv        Shed        0       4    2007       WD
# 1347         0     Gd  MnPrv        Shed        0       5    2007      New
# 1338         0     Gd  MnPrv        Shed        0       6    2006       WD
#
#      SaleCondition     SalePrice
# 1777        Normal  180921.19589
# 2901        Normal  180921.19589
# 2351        Normal  180921.19589
# 1347       Partial  283463.00000
# 1338        Normal  200000.00000

# %%
#ah_data.sample(10)

missing_values_count = ah_data.isnull().sum()
missing_values_count
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
# Street           0
# Alley            0
# LotShape         0
# LandContour      0
# Utilities        0
# LotConfig        0
# LandSlope        0
# Neighborhood     0
# Condition1       0
# Condition2       0
# BldgType         0
# HouseStyle       0
# OverallQual      0
# OverallCond      0
# YearBuilt        0
# YearRemodAdd     0
# RoofStyle        0
# RoofMatl         0
# Exterior1st      0
# Exterior2nd      0
# MasVnrType       0
# MasVnrArea       0
# ExterQual        0
# ExterCond        0
# Foundation       0
# BsmtQual         0
# BsmtCond         0
# BsmtExposure     0
# BsmtFinType1     0
# BsmtFinSF1       0
# BsmtFinType2     0
# BsmtFinSF2       0
# BsmtUnfSF        0
# TotalBsmtSF      0
# Heating          0
# HeatingQC        0
# CentralAir       0
# Electrical       0
# 1stFlrSF         0
# 2ndFlrSF         0
# LowQualFinSF     0
# GrLivArea        0
# BsmtFullBath     0
# BsmtHalfBath     0
# FullBath         0
# HalfBath         0
# BedroomAbvGr     0
# KitchenAbvGr     0
# KitchenQual      0
# TotRmsAbvGrd     0
# Functional       0
# Fireplaces       0
# FireplaceQu      0
# GarageType       0
# GarageYrBlt      0
# GarageFinish     0
# GarageCars       0
# GarageArea       0
# GarageQual       0
# GarageCond       0
# PavedDrive       0
# WoodDeckSF       0
# OpenPorchSF      0
# EnclosedPorch    0
# 3SsnPorch        0
# ScreenPorch      0
# PoolArea         0
# PoolQC           0
# Fence            0
# MiscFeature      0
# MiscVal          0
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
# dtype: int64
